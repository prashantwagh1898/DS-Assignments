# %%
#import hierarchical clustering libraries
import scipy.cluster.hierarchy as sch 
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sn

# %%
airlinev=pd.read_excel("EastWestAirlines.xlsx",sheet_name='data')

# %%
airlinev.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
# EDA and Visualization
data = airlinev.info()
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
data = airlinev.info
data
# Out:
# <bound method DataFrame.info of        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?
# 0          0
# 1          0
# 2          0
# 3          0
# 4          1
# ...      ...
# 3994       1
# 3995       1
# 3996       1
# 3997       0
# 3998       0
#
# [3999 rows x 12 columns]>

# %%
data = airlinev[airlinev.duplicated()].shape
data
# Out:
# (0, 12)

# %%
data=airlinev[airlinev.duplicated()]
data
# Out:
# Empty DataFrame
# Columns: [ID#, Balance, Qual_miles, cc1_miles, cc2_miles, cc3_miles, Bonus_miles, Bonus_trans, Flight_miles_12mo, Flight_trans_12, Days_since_enroll, Award?]
# Index: []

# %%
data = airlinev.drop(['ID#','Award?'],axis=1)
data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
# [3999 rows x 10 columns]

# %%
data.corr()
# Out:
#                     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# Balance            1.000000    0.108722   0.338344  -0.008804   0.035243
# Qual_miles         0.108722    1.000000   0.007931  -0.013923  -0.007779
# cc1_miles          0.338344    0.007931   1.000000  -0.068223   0.060555
# cc2_miles         -0.008804   -0.013923  -0.068223   1.000000  -0.006166
# cc3_miles          0.035243   -0.007779   0.060555  -0.006166   1.000000
# Bonus_miles        0.403487    0.031021   0.825200  -0.003969   0.204134
# Bonus_trans        0.324935    0.050725   0.608943   0.064399   0.097313
# Flight_miles_12mo  0.217551    0.126774   0.037370   0.010598  -0.001777
# Flight_trans_12    0.255700    0.144004   0.041333   0.028284  -0.001117
# Days_since_enroll  0.263129    0.017312   0.230849  -0.005807   0.010832
#
#                    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# Balance               0.403487     0.324935           0.217551
# Qual_miles            0.031021     0.050725           0.126774
# cc1_miles             0.825200     0.608943           0.037370
# cc2_miles            -0.003969     0.064399           0.010598
# cc3_miles             0.204134     0.097313          -0.001777
# Bonus_miles           1.000000     0.603180           0.183536
# Bonus_trans           0.603180     1.000000           0.377216
# Flight_miles_12mo     0.183536     0.377216           1.000000
# Flight_trans_12       0.185261     0.432364           0.869193
# Days_since_enroll     0.210397     0.161262           0.037271
#
#                    Flight_trans_12  Days_since_enroll
# Balance                   0.255700           0.263129
# Qual_miles                0.144004           0.017312
# cc1_miles                 0.041333           0.230849
# cc2_miles                 0.028284          -0.005807
# cc3_miles                -0.001117           0.010832
# Bonus_miles               0.185261           0.210397
# Bonus_trans               0.432364           0.161262
# Flight_miles_12mo         0.869193           0.037271
# Flight_trans_12           1.000000           0.059260
# Days_since_enroll         0.059260           1.000000

# %%
#visualization
import seaborn as sns
sns.set_style(style='darkgrid')
sns.pairplot(data)

# %%
from sklearn import preprocessing
data_norm = preprocessing.scale(data)

# %%
data_norm = pd.DataFrame(data_norm) #standardize the data to normal distrinct

# %%
data_norm.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.451141 -0.186299 -0.769578 -0.098242 -0.062767 -0.702786 -1.104065
# 1 -0.539457 -0.186299 -0.769578 -0.098242 -0.062767 -0.701088 -0.999926
# 2 -0.320031 -0.186299 -0.769578 -0.098242 -0.062767 -0.539253 -0.791649
# 3 -0.583799 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286 -1.104065
# 4  0.239678 -0.186299  1.409471 -0.098242 -0.062767  1.083121  1.499394
#
#           7         8         9
# 0 -0.328603 -0.362168  1.395454
# 1 -0.328603 -0.362168  1.379957
# 2 -0.328603 -0.362168  1.411920
# 3 -0.328603 -0.362168  1.372208
# 4  1.154932  0.692490  1.363975

# %% [markdown]
# # Finding out the optimal number of clusters

# %%
from sklearn.cluster import KMeans
plt.figure(figsize=(10, 8))
wcss = []
for i in range(1, 15):
    kmeans = KMeans(n_clusters = i,init = 'k-means++', random_state = 42)
    kmeans.fit(data_norm)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 15), wcss)
plt.plot('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# # H Clustering Euclidean distance, Ward

# %%
dendrogram = sch.dendrogram(sch.linkage(data_norm, method='ward'))

# %%
X = data_norm.values

# %%
model = AgglomerativeClustering(n_clusters=3, affinity='euclidean')

# %%
h_cluster = model.fit(X)

# %%
labels = model.labels_

# %%
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')

# %% [markdown]
# # K Means

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
k_means = kmeans.fit_predict(data_norm)

# %%
k_means
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
k_means1=k_means+1
k_cluster = list(k_means1)

# %%
data['k_cluster'] = k_cluster

# %%
kmeans_mean_cluster = pd.DataFrame(round(data.groupby('k_cluster').mean(),1))

# %%
kmeans_mean_cluster
# Out:
#             Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# k_cluster
# 1           42723.4       104.5        1.2        1.0        1.0       4341.8
# 2          115547.1       138.7        3.7        1.0        1.0      38945.5
# 3          198856.6       790.4        2.2        1.0        1.0      32951.2
#
#            Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# k_cluster
# 1                  6.7              213.2              0.6             3695.5
# 2                 18.8              316.9              0.9             4827.2
# 3                 27.4             5383.1             15.9             4737.5

# %%
pd.DataFrame(round(data.groupby('k_cluster').count(),1))
# Out:
#            Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# k_cluster
# 1             2491        2491       2491       2491       2491         2491
# 2             1344        1344       1344       1344       1344         1344
# 3              164         164        164        164        164          164
#
#            Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# k_cluster
# 1                 2491               2491             2491               2491
# 2                 1344               1344             1344               1344
# 3                  164                164              164                164

# %%
plt.scatter(X[:, 0], X[:, 1], c=k_means, s=50, cmap='viridis')

# %% [markdown]
# # DBSCAN

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
array=data.values
array
# Out:
# array([[28143,     0,     1, ...,     0,  7000,     1],
#        [19244,     0,     1, ...,     0,  6968,     1],
#        [41354,     0,     1, ...,     0,  7034,     1],
#        ...,
#        [73597,     0,     3, ...,     0,  1402,     1],
#        [54899,     0,     1, ...,     1,  1401,     1],
#        [ 3016,     0,     1, ...,     0,  1398,     1]], dtype=int64)

# %%
stscaler = StandardScaler().fit(array)
X = stscaler.transform(array)
X
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.33050231e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.33050231e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.33050231e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00, -7.33050231e-01],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.33050231e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.33050231e-01]])

# %%
dbscan = DBSCAN(eps=0.8, min_samples=6)
dbscan.fit(X)
# Out:
# DBSCAN(eps=0.8, min_samples=6)

# %%
#Noisy samples are given the label -1.
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
cl=pd.DataFrame(dbscan.labels_,columns=['cluster'])
cl
# Out:
#       cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4          -1
# ...       ...
# 3994        0
# 3995        0
# 3996        0
# 3997        0
# 3998        0
#
# [3999 rows x 1 columns]

# %%
pd.concat([data,cl],axis=1)
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       k_cluster  cluster
# 0             1        0
# 1             1        0
# 2             1        0
# 3             1        0
# 4             2       -1
# ...         ...      ...
# 3994          1        0
# 3995          1        0
# 3996          1        0
# 3997          1        0
# 3998          1        0
#
# [3999 rows x 12 columns]
